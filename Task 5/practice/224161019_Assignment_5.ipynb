# %% [markdown]
# ML Lab5 : Neelmani- 224161019

# %%
import numpy as np
import pandas as pd
from sympy import symbols, diff
import sympy as sy
from sympy.functions import *
from sympy.utilities.lambdify import lambdify
from matplotlib import cm
import matplotlib.pyplot as plt
import random

# %% [markdown]
# Question 1

# %%
def f(x,y):
  z1= 1.7*exp(-(((x-3)**2)/10 + ((y-3)**2)/10) ) + exp(-(((x+5)**2)/8 + ((y+5)**2)/8) ) + 2*exp(-(((x)**2)/4 + ((y)**2)/5) ) + 1.5*exp(-(((x-4)**2)/18 + ((y+4)**2)/16) ) + 1.2*exp(-(((x+4)**2)/18 + ((y-4)**2)/16) )
  return z1

def stochasticSearch(xmin, xmax, ymin, ymax, popSize, nbhSize, maxItr):
    
    x = np.linspace(-10,10,100)
    y = np.linspace(-10,10,100)
    zz = np.zeros((100,100))

    xx, yy = np.meshgrid(x, y)
    zz = np.zeros((len(x), len(y)))
    for i in range(len(x)):
      for j in range(len(y)):
        zz[i][j] = f(x[i], y[j])

    
    alpha_x = np.random.uniform(0,1,popSize)
    x = alpha_x*xmin+(1-alpha_x)*xmax
    alpha_y = np.random.uniform(0,1,popSize)
    y = alpha_y*ymin+(1-alpha_y)*ymax
    n = int(np.floor(popSize/10))
    
    plt.contourf(xx, yy, zz, cmap='viridis')
    plt.scatter(x,y);
    plt.show()
    
    for iters in range(maxItr):
        z=np.zeros(len(x))
        for i in range(len(x)):
          z[i] = f(x[i],y[i])
        z=z-z.min()
        z1=z.sum()
        p=z/z1
        ch=np.zeros(len(p))
        for i in  range(len(p)):
          ch[i]=int(np.round(popSize*p[i]))
        
        temp_x = x
        temp_y = y
        x = []
        y = []

        for i in range(len(ch)):
          x.append(temp_x[i])
          y.append(temp_y[i])
          if ch[i] > 0:
            r = nbhSize*np.random.rand(int(ch[i]))
            theta = 2*(np.pi)*np.random.rand(int(ch[i]))
            for j in range(len(r)):
                x.append(temp_x[i]+ r[j]*np.cos(theta[j]))
                y.append(temp_y[i]+ r[j]*np.sin(theta[j]))
                
        x = np.array(x)
        y = np.array(y)
        z=np.zeros(len(x))
        for i in range(len(x)):
          z[i] = f(x[i],y[i])
        idx = np.argsort(z)[::-1][:30]
        z=z[idx]
        x=x[idx]
        y=y[idx]
  
        print( iters+1," iteration: ")
        plt.contourf(xx, yy, zz,cmap='viridis')
        plt.scatter(x,y);
        plt.show()
        
    index = z.argmax()
    bestX = x[index]
    bestY = y[index]
    maxF =  z[index]
    return bestX, bestY, maxF
  
x,y,z = stochasticSearch(-10, 10, -10, 10, 50, 2, 20)
print("bestX :: ",x)
print("bestY :: ",y)
print("bestZ :: ",z)

Xmin = -10
Xmax = 10
Ymin = -10
Ymax = 10
popSize = 50
nbhSize = 0.5
maxItr = 10
bestX, bestF, history = stochasticSearch(Xmin, Xmax,Ymin,Ymax, popSize, nbhSize, maxItr)
print("Best solution: x =", bestX, "f(x) =", bestF)
# Out:
# 1  iteration:
# 2  iteration:
# 3  iteration:
# 4  iteration:
# 5  iteration:
# 6  iteration:
# 7  iteration:
# 8  iteration:
# 9  iteration:
# 10  iteration:
# 11  iteration:
# 12  iteration:
# 13  iteration:
# 14  iteration:
# 15  iteration:
# 16  iteration:
# 17  iteration:
# 18  iteration:
# 19  iteration:
# 20  iteration:
# bestX ::  0.22398618479376514
# bestY ::  0.22883112395300303
# bestZ ::  2.7258040361253277
# 1  iteration:
# 2  iteration:
# 3  iteration:
# 4  iteration:
# 5  iteration:
# 6  iteration:
# 7  iteration:
# 8  iteration:
# 9  iteration:
# 10  iteration:
# Best solution: x = 0.2185391221862225 f(x) = 0.21136284232852381

# %% [markdown]
# Question 2

# %%
f=open("att48_xy.txt",'r')
xy_list=f.readlines()
f.close()
xy_list=[word[:-1] for word in xy_list]
x_list=np.array([int(word[:4]) for word in xy_list])
y_list=np.array([int(word[5:]) for word in xy_list])
S=np.row_stack((x_list,y_list))

f=open("att48_d.txt",'r')
d_list=f.readlines()
f.close()
d_list=[word[:-1] for word in d_list]
d_list=[word.split("      ")for word in d_list]
d_list=[lst[1:] for lst in d_list]
for i in range(len(d_list)):
    for j in range(len(d_list[i])):
        d_list[i][j]=int(d_list[i][j])
distance=np.array(d_list) # Contains distance between coordinates

plt.figure(figsize=(10,6))
plt.scatter(x_list,y_list)
plt.title("Locations")

tour_indices=list(range(1,48))
m=1000
itr=500
K=50
s=np.random.permutation(tour_indices)
for i in range(m-1):
    s=np.column_stack((s,np.random.permutation(tour_indices)))

for it in range(itr):
    distance_list=[]
    for i in range(s.shape[1]):
        d=distance[0][s[0,i]]
        for j in range(1,len(s[:,i])):
            d+=distance[s[j-1,i]][s[j,i]]
        d+=distance[0][s[len(s[:,i])-1,i]]
        distance_list.append(-d)
    Y=np.array(distance_list)
    
    # Evaluating solution fitness scores
    Y_min=Y.min()
    U=Y-Y_min
    U_sum=U.sum()
    P=U/U_sum # Fitness Scores
    
    children_size=np.round(P*m)
    children_size[np.isnan(children_size)] = 0
    children_list=[]
    for i in range(m):
        if children_size[i]==np.NaN:
            print(0)
        for j in range(int(children_size[i])):
            indices=np.random.randint(0,47,2)
            k=indices[0]
            l=indices[1]
            s_child=s[:,i].copy()
            s_child[[k,l]]=s_child[[l,k]]
            children_list.append(s_child)
            
    all_soln=s.copy()
    for i in range(len(children_list)):
                all_soln=np.column_stack((all_soln,children_list[i]))    
    distance_all=[]
    for i in range(all_soln.shape[1]):
        d=distance[0][all_soln[0,i]]
        for j in range(1,len(all_soln[:,i])):
            d+=distance[all_soln[j-1,i]][all_soln[j,i]]
        d+=distance[0][all_soln[len(all_soln[:,i])-1,i]]
        distance_all.append(-d)
        
    Y=-(np.array(distance_all))
    s=all_soln[:,Y.argsort()[:m]].copy()
    best_sol=s[:,0]
    print(f"Best value at iteration {it} is {Y[Y.argsort()[0]]}")
    if it%K==0:
        plt.figure(figsize=(10,6))
        plt.scatter(x_list,y_list,color='green')
        plt.scatter(x_list[0],y_list[0],color='red') # Starting and ending point
        plt.plot([x_list[0],x_list[best_sol[0]]],[y_list[0],y_list[best_sol[0]]],color='blue')
        for i in range(1,len(best_sol)):
            plt.plot([x_list[best_sol[i-1]],x_list[best_sol[i]]],[y_list[best_sol[i-1]],y_list[best_sol[i]]],color='blue')
        plt.plot([x_list[0],x_list[best_sol[-1]]],[y_list[0],y_list[best_sol[-1]]],color='blue')
        plt.show()
        

plt.figure(figsize=(10,6))
plt.scatter(x_list,y_list,color='green')
plt.scatter(x_list[0],y_list[0],color='red') # Starting and ending point
plt.plot([x_list[0],x_list[best_sol[0]]],[y_list[0],y_list[best_sol[0]]],color='blue')
for i in range(1,len(best_sol)):
    plt.plot([x_list[best_sol[i-1]],x_list[best_sol[i]]],[y_list[best_sol[i-1]],y_list[best_sol[i]]],color='blue')
plt.plot([x_list[0],x_list[best_sol[-1]]],[y_list[0],y_list[best_sol[-1]]],color='blue')
plt.title("Final Solution")
# Out:
# Best value at iteration 0 is 112800
# Best value at iteration 1 is 112174
# Best value at iteration 2 is 108794
# Best value at iteration 3 is 102745
# Best value at iteration 4 is 101549
# Best value at iteration 5 is 98559
# Best value at iteration 6 is 97344
# Best value at iteration 7 is 94240
# Best value at iteration 8 is 91574
# Best value at iteration 9 is 91109
# Best value at iteration 10 is 88782
# Best value at iteration 11 is 87778
# Best value at iteration 12 is 86322
# Best value at iteration 13 is 84351
# Best value at iteration 14 is 84319
# Best value at iteration 15 is 80835
# Best value at iteration 16 is 80835
# Best value at iteration 17 is 79186
# Best value at iteration 18 is 79152
# Best value at iteration 19 is 74729
# Best value at iteration 20 is 72704
# Best value at iteration 21 is 72284
# Best value at iteration 22 is 70275
# Best value at iteration 23 is 70260
# Best value at iteration 24 is 70260
# Best value at iteration 25 is 68648
# Best value at iteration 26 is 66731
# Best value at iteration 27 is 66731
# Best value at iteration 28 is 65301
# Best value at iteration 29 is 65301
# Best value at iteration 30 is 65182
# Best value at iteration 31 is 65149
# Best value at iteration 32 is 63967
# Best value at iteration 33 is 63967
# Best value at iteration 34 is 63929
# Best value at iteration 35 is 61559
# Best value at iteration 36 is 59710
# Best value at iteration 37 is 58489
# Best value at iteration 38 is 58489
# Best value at iteration 39 is 58489
# Best value at iteration 40 is 56857
# Best value at iteration 41 is 56857
# Best value at iteration 42 is 56857
# Best value at iteration 43 is 56857
# Best value at iteration 44 is 56180
# Best value at iteration 45 is 56089
# Best value at iteration 46 is 54570
# Best value at iteration 47 is 54570
# Best value at iteration 48 is 54337
# Best value at iteration 49 is 54337
# Best value at iteration 50 is 54337
# Best value at iteration 51 is 54025
# Best value at iteration 52 is 54025
# Best value at iteration 53 is 53008
# Best value at iteration 54 is 53008
# Best value at iteration 55 is 52819
# Best value at iteration 56 is 52778
# Best value at iteration 57 is 51611
# Best value at iteration 58 is 49658
# Best value at iteration 59 is 49658
# Best value at iteration 60 is 49658
# Best value at iteration 61 is 49658
# Best value at iteration 62 is 49653
# Best value at iteration 63 is 49266
# Best value at iteration 64 is 49266
# Best value at iteration 65 is 48661
# Best value at iteration 66 is 48661
# Best value at iteration 67 is 48661
# Best value at iteration 68 is 48437
# Best value at iteration 69 is 48437
# Best value at iteration 70 is 48437
# Best value at iteration 71 is 47742
# Best value at iteration 72 is 47698
# Best value at iteration 73 is 47698
# Best value at iteration 74 is 47464
# Best value at iteration 75 is 46656
# Best value at iteration 76 is 46656
# Best value at iteration 77 is 46656
# Best value at iteration 78 is 46656
# Best value at iteration 79 is 46615
# Best value at iteration 80 is 45876
# Best value at iteration 81 is 45876
# Best value at iteration 82 is 45876
# Best value at iteration 83 is 45272
# Best value at iteration 84 is 45272
# Best value at iteration 85 is 45272
# Best value at iteration 86 is 45272
# Best value at iteration 87 is 45200
# Best value at iteration 88 is 45200
# Best value at iteration 89 is 45180
# Best value at iteration 90 is 45123
# Best value at iteration 91 is 44944
# Best value at iteration 92 is 44944
# Best value at iteration 93 is 44922
# Best value at iteration 94 is 44914
# Best value at iteration 95 is 44914
# Best value at iteration 96 is 44540
# Best value at iteration 97 is 44527
# Best value at iteration 98 is 44358
# Best value at iteration 99 is 44358
# Best value at iteration 100 is 44358
# Best value at iteration 101 is 44358
# Best value at iteration 102 is 44074
# Best value at iteration 103 is 44038
# Best value at iteration 104 is 43761
# Best value at iteration 105 is 43761
# Best value at iteration 106 is 43761
# Best value at iteration 107 is 43535
# Best value at iteration 108 is 43506
# Best value at iteration 109 is 43506
# Best value at iteration 110 is 43506
# Best value at iteration 111 is 43506
# Best value at iteration 112 is 43506
# Best value at iteration 113 is 43506
# Best value at iteration 114 is 43506
# Best value at iteration 115 is 43506
# Best value at iteration 116 is 43506
# Best value at iteration 117 is 43506
# Best value at iteration 118 is 43337
# Best value at iteration 119 is 43337
# Best value at iteration 120 is 42843
# Best value at iteration 121 is 42843
# Best value at iteration 122 is 42843
# Best value at iteration 123 is 42843
# Best value at iteration 124 is 42826
# Best value at iteration 125 is 42826
# Best value at iteration 126 is 42826
# Best value at iteration 127 is 42826
# Best value at iteration 128 is 42826
# Best value at iteration 129 is 42826
# Best value at iteration 130 is 42826
# Best value at iteration 131 is 42723
# Best value at iteration 132 is 42723
# Best value at iteration 133 is 42723
# Best value at iteration 134 is 42723
# Best value at iteration 135 is 42723
# Best value at iteration 136 is 42723
# Best value at iteration 137 is 42723
# Best value at iteration 138 is 42723
# Best value at iteration 139 is 42723
# Best value at iteration 140 is 42566
# Best value at iteration 141 is 42235
# Best value at iteration 142 is 42235
# Best value at iteration 143 is 42235
# Best value at iteration 144 is 42235
# Best value at iteration 145 is 42235
# Best value at iteration 146 is 42235
# Best value at iteration 147 is 42235
# Best value at iteration 148 is 42235
# Best value at iteration 149 is 42235
# Best value at iteration 150 is 42235
# Best value at iteration 151 is 42235
# Best value at iteration 152 is 42235
# Best value at iteration 153 is 42235
# Best value at iteration 154 is 42112
# Best value at iteration 155 is 42112
# Best value at iteration 156 is 42112
# Best value at iteration 157 is 42112
# Best value at iteration 158 is 41930
# Best value at iteration 159 is 41930
# Best value at iteration 160 is 41731
# Best value at iteration 161 is 41731
# Best value at iteration 162 is 41731
# Best value at iteration 163 is 41731
# Best value at iteration 164 is 41731
# Best value at iteration 165 is 41731
# Best value at iteration 166 is 41731
# Best value at iteration 167 is 41731
# Best value at iteration 168 is 41731
# Best value at iteration 169 is 41731
# Best value at iteration 170 is 41731
# Best value at iteration 171 is 41084
# Best value at iteration 172 is 40611
# Best value at iteration 173 is 40611
# Best value at iteration 174 is 40611
# Best value at iteration 175 is 40611
# Best value at iteration 176 is 40611
# Best value at iteration 177 is 40611
# Best value at iteration 178 is 40611
# Best value at iteration 179 is 40611
# Best value at iteration 180 is 40611
# Best value at iteration 181 is 40611
# Best value at iteration 182 is 40611
# Best value at iteration 183 is 40611
# Best value at iteration 184 is 40611
# Best value at iteration 185 is 40327
# Best value at iteration 186 is 40327
# Best value at iteration 187 is 40327
# Best value at iteration 188 is 40327
# Best value at iteration 189 is 40327
# Best value at iteration 190 is 40327
# Best value at iteration 191 is 40327
# Best value at iteration 192 is 40327
# Best value at iteration 193 is 40327
# Best value at iteration 194 is 40327
# Best value at iteration 195 is 40327
# Best value at iteration 196 is 40327
# Best value at iteration 197 is 40327
# Best value at iteration 198 is 40327
# Best value at iteration 199 is 40327
# Best value at iteration 200 is 40327
# Best value at iteration 201 is 40327
# Best value at iteration 202 is 40327
# Best value at iteration 203 is 40327
# Best value at iteration 204 is 40327
# Best value at iteration 205 is 40327
# Best value at iteration 206 is 40327
# Best value at iteration 207 is 40327
# Best value at iteration 208 is 40327
# Best value at iteration 209 is 40260
# Best value at iteration 210 is 40260
# Best value at iteration 211 is 40260
# Best value at iteration 212 is 40260
# Best value at iteration 213 is 40260
# Best value at iteration 214 is 40260
# Best value at iteration 215 is 40260
# Best value at iteration 216 is 40260
# Best value at iteration 217 is 40260
# Best value at iteration 218 is 40260
# Best value at iteration 219 is 40260
# Best value at iteration 220 is 40260
# Best value at iteration 221 is 40260
# Best value at iteration 222 is 40260
# Best value at iteration 223 is 40260
# Best value at iteration 224 is 40260
# Best value at iteration 225 is 40260
# Best value at iteration 226 is 40260
# Best value at iteration 227 is 40220
# Best value at iteration 228 is 40220
# Best value at iteration 229 is 40220
# Best value at iteration 230 is 40220
# Best value at iteration 231 is 40220
# Best value at iteration 232 is 40220
# Best value at iteration 233 is 40220
# Best value at iteration 234 is 40220
# Best value at iteration 235 is 40220
# Best value at iteration 236 is 40220
# Best value at iteration 237 is 40220
# Best value at iteration 238 is 40220
# Best value at iteration 239 is 40220
# Best value at iteration 240 is 40220
# Best value at iteration 241 is 40220
# Best value at iteration 242 is 40220
# Best value at iteration 243 is 40220
# Best value at iteration 244 is 40220
# Best value at iteration 245 is 40220
# Best value at iteration 246 is 40220
# Best value at iteration 247 is 40032
# Best value at iteration 248 is 40032
# Best value at iteration 249 is 40032
# Best value at iteration 250 is 40032
# Best value at iteration 251 is 40032
# Best value at iteration 252 is 39755
# Best value at iteration 253 is 39755
# Best value at iteration 254 is 39755
# Best value at iteration 255 is 39755
# Best value at iteration 256 is 39755
# Best value at iteration 257 is 39755
# Best value at iteration 258 is 39755
# Best value at iteration 259 is 39755
# Best value at iteration 260 is 39755
# Best value at iteration 261 is 39755
# Best value at iteration 262 is 39755
# Best value at iteration 263 is 39755
# Best value at iteration 264 is 39755
# Best value at iteration 265 is 39755
# Best value at iteration 266 is 39755
# Best value at iteration 267 is 39755
# Best value at iteration 268 is 39755
# Best value at iteration 269 is 39755
# Best value at iteration 270 is 39755
# Best value at iteration 271 is 39755
# Best value at iteration 272 is 39755
# Best value at iteration 273 is 39755
# Best value at iteration 274 is 39755
# Best value at iteration 275 is 39755
# Best value at iteration 276 is 39755
# Best value at iteration 277 is 39755
# Best value at iteration 278 is 39755
# Best value at iteration 279 is 39755
# Best value at iteration 280 is 39755
# Best value at iteration 281 is 39755
# Best value at iteration 282 is 39755
# Best value at iteration 283 is 39755
# Best value at iteration 284 is 39755
# Best value at iteration 285 is 39755
# Best value at iteration 286 is 39755
# Best value at iteration 287 is 39755
# Best value at iteration 288 is 39755
# Best value at iteration 289 is 39755
# Best value at iteration 290 is 39755
# Best value at iteration 291 is 39755
# Best value at iteration 292 is 39755
# Best value at iteration 293 is 39755
# Best value at iteration 294 is 39755
# Best value at iteration 295 is 39755
# Best value at iteration 296 is 39755
# Best value at iteration 297 is 39755
# Best value at iteration 298 is 39755
# Best value at iteration 299 is 39755
# Best value at iteration 300 is 39755
# Best value at iteration 301 is 39755
# Best value at iteration 302 is 39755
# Best value at iteration 303 is 39755
# Best value at iteration 304 is 39755
# Best value at iteration 305 is 39755
# Best value at iteration 306 is 39755
# Best value at iteration 307 is 39755
# Best value at iteration 308 is 39755
# Best value at iteration 309 is 39701
# Best value at iteration 310 is 39701
# Best value at iteration 311 is 39701
# Best value at iteration 312 is 39701
# Best value at iteration 313 is 39701
# Best value at iteration 314 is 39701
# Best value at iteration 315 is 39701
# Best value at iteration 316 is 39701
# Best value at iteration 317 is 39701
# Best value at iteration 318 is 39701
# Best value at iteration 319 is 39701
# Best value at iteration 320 is 39701
# Best value at iteration 321 is 39701
# Best value at iteration 322 is 39701
# Best value at iteration 323 is 39701
# Best value at iteration 324 is 39701
# Best value at iteration 325 is 39701
# Best value at iteration 326 is 39701
# Best value at iteration 327 is 39701
# Best value at iteration 328 is 39701
# Best value at iteration 329 is 39701
# Best value at iteration 330 is 39701
# Best value at iteration 331 is 39701
# Best value at iteration 332 is 39701
# Best value at iteration 333 is 39701
# Best value at iteration 334 is 39701
# Best value at iteration 335 is 39701
# Best value at iteration 336 is 39701
# Best value at iteration 337 is 39701
# Best value at iteration 338 is 39701
# Best value at iteration 339 is 39701
# Best value at iteration 340 is 39701
# Best value at iteration 341 is 39701
# Best value at iteration 342 is 39701
# Best value at iteration 343 is 39701
# Best value at iteration 344 is 39701
# Best value at iteration 345 is 39701
# Best value at iteration 346 is 39701
# Best value at iteration 347 is 39701
# Best value at iteration 348 is 39701
# Best value at iteration 349 is 39701
# Best value at iteration 350 is 39701
# Best value at iteration 351 is 39701
# Best value at iteration 352 is 39701
