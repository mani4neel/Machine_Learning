# %% [markdown]
# ML Lab5 : Neelmani- 224161019

# %%
import numpy as np
import pandas as pd
from sympy import symbols, diff
import sympy as sy
from sympy.functions import *
from sympy.utilities.lambdify import lambdify
from matplotlib import cm
import matplotlib.pyplot as plt
import random

# %% [markdown]
# Question 1

# %%
def f(x,y):
  z1= 1.7*exp(-(((x-3)**2)/10 + ((y-3)**2)/10) ) + exp(-(((x+5)**2)/8 + ((y+5)**2)/8) ) + 2*exp(-(((x)**2)/4 + ((y)**2)/5) ) + 1.5*exp(-(((x-4)**2)/18 + ((y+4)**2)/16) ) + 1.2*exp(-(((x+4)**2)/18 + ((y-4)**2)/16) )
  return z1

def stochasticSearch(xmin, xmax, ymin, ymax, popSize, nbhSize, maxItr):
    
    x = np.linspace(-10,10,100)
    y = np.linspace(-10,10,100)
    zz = np.zeros((100,100))

    xx, yy = np.meshgrid(x, y)
    zz = np.zeros((len(x), len(y)))
    for i in range(len(x)):
      for j in range(len(y)):
        zz[i][j] = f(x[i], y[j])

    
    alpha_x = np.random.uniform(0,1,popSize)
    x = alpha_x*xmin+(1-alpha_x)*xmax
    alpha_y = np.random.uniform(0,1,popSize)
    y = alpha_y*ymin+(1-alpha_y)*ymax
    n = int(np.floor(popSize/10))
    
    plt.contourf(xx, yy, zz, cmap='viridis')
    plt.scatter(x,y);
    plt.show()
    
    for iters in range(maxItr):
        z=np.zeros(len(x))
        for i in range(len(x)):
          z[i] = f(x[i],y[i])
        z=z-z.min()
        z1=z.sum()
        p=z/z1
        ch=np.zeros(len(p))
        for i in  range(len(p)):
          ch[i]=int(np.round(popSize*p[i]))
        
        temp_x = x
        temp_y = y
        x = []
        y = []

        for i in range(len(ch)):
          x.append(temp_x[i])
          y.append(temp_y[i])
          if ch[i] > 0:
            r = nbhSize*np.random.rand(int(ch[i]))
            theta = 2*(np.pi)*np.random.rand(int(ch[i]))
            for j in range(len(r)):
                x.append(temp_x[i]+ r[j]*np.cos(theta[j]))
                y.append(temp_y[i]+ r[j]*np.sin(theta[j]))
                
        x = np.array(x)
        y = np.array(y)
        z=np.zeros(len(x))
        for i in range(len(x)):
          z[i] = f(x[i],y[i])
        idx = np.argsort(z)[::-1][:30]
        z=z[idx]
        x=x[idx]
        y=y[idx]
  
        print( iters+1," iteration: ")
        plt.contourf(xx, yy, zz,cmap='viridis')
        plt.scatter(x,y);
        plt.show()
        
    index = z.argmax()
    bestX = x[index]
    bestY = y[index]
    maxF =  z[index]
    return bestX, bestY, maxF
  
x,y,z = stochasticSearch(-10, 10, -10, 10, 50, 2, 20)
print("bestX :: ",x)
print("bestY :: ",y)
print("bestZ :: ",z)

Xmin = -10
Xmax = 10
Ymin = -10
Ymax = 10
popSize = 50
nbhSize = 0.5
maxItr = 10
bestX, bestF, history = stochasticSearch(Xmin, Xmax,Ymin,Ymax, popSize, nbhSize, maxItr)
print("Best solution: x =", bestX, "f(x) =", bestF)
# Out:
# 1  iteration:
# 2  iteration:
# 3  iteration:
# 4  iteration:
# 5  iteration:
# 6  iteration:
# 7  iteration:
# 8  iteration:
# 9  iteration:
# 10  iteration:
# 11  iteration:
# 12  iteration:
# 13  iteration:
# 14  iteration:
# 15  iteration:
# 16  iteration:
# 17  iteration:
# 18  iteration:
# 19  iteration:
# 20  iteration:
# bestX ::  0.22398618479376514
# bestY ::  0.22883112395300303
# bestZ ::  2.7258040361253277
# 1  iteration:
# 2  iteration:
# 3  iteration:
# 4  iteration:
# 5  iteration:
# 6  iteration:
# 7  iteration:
# 8  iteration:
# 9  iteration:
# 10  iteration:
# Best solution: x = 0.2185391221862225 f(x) = 0.21136284232852381

# %% [markdown]
# Question 2

# %%
f=open("att48_xy.txt",'r')
xy_list=f.readlines()
f.close()
xy_list=[word[:-1] for word in xy_list]
x_list=np.array([int(word[:4]) for word in xy_list])
y_list=np.array([int(word[5:]) for word in xy_list])
S=np.row_stack((x_list,y_list))

f=open("att48_d.txt",'r')
d_list=f.readlines()
f.close()
d_list=[word[:-1] for word in d_list]
d_list=[word.split("      ")for word in d_list]
d_list=[lst[1:] for lst in d_list]
for i in range(len(d_list)):
    for j in range(len(d_list[i])):
        d_list[i][j]=int(d_list[i][j])
distance=np.array(d_list) # Contains distance between coordinates

plt.figure(figsize=(10,6))
plt.scatter(x_list,y_list)
plt.title("Locations")

tour_indices=list(range(1,48))
m=1000
itr=500
K=50
s=np.random.permutation(tour_indices)
for i in range(m-1):
    s=np.column_stack((s,np.random.permutation(tour_indices)))

for it in range(itr):
    distance_list=[]
    for i in range(s.shape[1]):
        d=distance[0][s[0,i]]
        for j in range(1,len(s[:,i])):
            d+=distance[s[j-1,i]][s[j,i]]
        d+=distance[0][s[len(s[:,i])-1,i]]
        distance_list.append(-d)
    Y=np.array(distance_list)
    
    # Evaluating solution fitness scores
    Y_min=Y.min()
    U=Y-Y_min
    U_sum=U.sum()
    P=U/U_sum # Fitness Scores
    
    children_size=np.round(P*m)
    children_size[np.isnan(children_size)] = 0
    children_list=[]
    for i in range(m):
        if children_size[i]==np.NaN:
            print(0)
        for j in range(int(children_size[i])):
            indices=np.random.randint(0,47,2)
            k=indices[0]
            l=indices[1]
            s_child=s[:,i].copy()
            s_child[[k,l]]=s_child[[l,k]]
            children_list.append(s_child)
            
    all_soln=s.copy()
    for i in range(len(children_list)):
                all_soln=np.column_stack((all_soln,children_list[i]))    
    distance_all=[]
    for i in range(all_soln.shape[1]):
        d=distance[0][all_soln[0,i]]
        for j in range(1,len(all_soln[:,i])):
            d+=distance[all_soln[j-1,i]][all_soln[j,i]]
        d+=distance[0][all_soln[len(all_soln[:,i])-1,i]]
        distance_all.append(-d)
        
    Y=-(np.array(distance_all))
    s=all_soln[:,Y.argsort()[:m]].copy()
    best_sol=s[:,0]
    print(f"Best value at iteration {it} is {Y[Y.argsort()[0]]}")
    if it%K==0:
        plt.figure(figsize=(10,6))
        plt.scatter(x_list,y_list,color='green')
        plt.scatter(x_list[0],y_list[0],color='red') # Starting and ending point
        plt.plot([x_list[0],x_list[best_sol[0]]],[y_list[0],y_list[best_sol[0]]],color='blue')
        for i in range(1,len(best_sol)):
            plt.plot([x_list[best_sol[i-1]],x_list[best_sol[i]]],[y_list[best_sol[i-1]],y_list[best_sol[i]]],color='blue')
        plt.plot([x_list[0],x_list[best_sol[-1]]],[y_list[0],y_list[best_sol[-1]]],color='blue')
        plt.show()
        

plt.figure(figsize=(10,6))
plt.scatter(x_list,y_list,color='green')
plt.scatter(x_list[0],y_list[0],color='red') # Starting and ending point
plt.plot([x_list[0],x_list[best_sol[0]]],[y_list[0],y_list[best_sol[0]]],color='blue')
for i in range(1,len(best_sol)):
    plt.plot([x_list[best_sol[i-1]],x_list[best_sol[i]]],[y_list[best_sol[i-1]],y_list[best_sol[i]]],color='blue')
plt.plot([x_list[0],x_list[best_sol[-1]]],[y_list[0],y_list[best_sol[-1]]],color='blue')
plt.title("Final Solution")
# Out:
# Best value at iteration 0 is 118206
# Best value at iteration 1 is 117844
# Best value at iteration 2 is 113321
# Best value at iteration 3 is 107730
# Best value at iteration 4 is 104374
# Best value at iteration 5 is 102765
# Best value at iteration 6 is 99444
# Best value at iteration 7 is 98527
# Best value at iteration 8 is 95559
# Best value at iteration 9 is 93380
# Best value at iteration 10 is 92316
# Best value at iteration 11 is 91067
# Best value at iteration 12 is 91004
# Best value at iteration 13 is 84981
# Best value at iteration 14 is 84981
# Best value at iteration 15 is 79696
# Best value at iteration 16 is 79696
# Best value at iteration 17 is 79437
# Best value at iteration 18 is 79437
# Best value at iteration 19 is 77272
# Best value at iteration 20 is 76633
# Best value at iteration 21 is 72749
# Best value at iteration 22 is 72749
# Best value at iteration 23 is 72420
# Best value at iteration 24 is 70792
# Best value at iteration 25 is 70792
# Best value at iteration 26 is 68121
# Best value at iteration 27 is 67426
# Best value at iteration 28 is 67426
# Best value at iteration 29 is 67197
# Best value at iteration 30 is 66161
# Best value at iteration 31 is 66021
# Best value at iteration 32 is 63793
# Best value at iteration 33 is 63793
# Best value at iteration 34 is 63547
# Best value at iteration 35 is 63547
# Best value at iteration 36 is 63084
# Best value at iteration 37 is 63084
# Best value at iteration 38 is 62708
# Best value at iteration 39 is 59127
# Best value at iteration 40 is 59127
# Best value at iteration 41 is 59127
# Best value at iteration 42 is 58678
# Best value at iteration 43 is 57248
# Best value at iteration 44 is 57248
# Best value at iteration 45 is 57248
# Best value at iteration 46 is 57248
# Best value at iteration 47 is 56409
# Best value at iteration 48 is 56315
# Best value at iteration 49 is 56315
# Best value at iteration 50 is 56315
# Best value at iteration 51 is 55969
# Best value at iteration 52 is 55969
# Best value at iteration 234 is 41368
# Best value at iteration 235 is 41368
# Best value at iteration 236 is 41368
# Best value at iteration 237 is 41368
# Best value at iteration 238 is 41368
# Best value at iteration 239 is 41368
# Best value at iteration 240 is 41368
# Best value at iteration 241 is 41368
# Best value at iteration 242 is 41368
# Best value at iteration 243 is 41368
# Best value at iteration 244 is 41368
# Best value at iteration 245 is 41273
# Best value at iteration 246 is 41273
# Best value at iteration 247 is 41273
# Best value at iteration 248 is 41273
# Best value at iteration 249 is 41273
# Best value at iteration 250 is 41273
# Best value at iteration 251 is 41273
# Best value at iteration 252 is 41273
# Best value at iteration 253 is 41273
# Best value at iteration 254 is 41104
# Best value at iteration 255 is 41104
# Best value at iteration 256 is 41104
# Best value at iteration 257 is 41104
# Best value at iteration 258 is 41104
# Best value at iteration 259 is 41104
# Best value at iteration 260 is 41104
# Best value at iteration 261 is 41104
# Best value at iteration 262 is 41104
# Best value at iteration 263 is 41084
# Best value at iteration 264 is 41084
# Best value at iteration 265 is 41084
# Best value at iteration 266 is 41084
# Best value at iteration 267 is 41068
# Best value at iteration 268 is 41068
# Best value at iteration 269 is 41068
# Best value at iteration 270 is 41068
# Best value at iteration 271 is 41068
# Best value at iteration 272 is 41068
# Best value at iteration 273 is 40867
# Best value at iteration 274 is 40867
# Best value at iteration 275 is 40867
# Best value at iteration 276 is 40867
# Best value at iteration 277 is 40867
# Best value at iteration 278 is 40867
# Best value at iteration 279 is 40867
# Best value at iteration 280 is 40867
# Best value at iteration 281 is 40867
# Best value at iteration 282 is 40867
# Best value at iteration 283 is 40867
# Best value at iteration 284 is 40867
# Best value at iteration 285 is 40867
# Best value at iteration 286 is 40867
# Best value at iteration 287 is 40867
# Best value at iteration 288 is 40867
# Best value at iteration 289 is 40867
# Best value at iteration 290 is 40867
# Best value at iteration 291 is 40867
# Best value at iteration 292 is 40867
# Best value at iteration 293 is 40867
# Best value at iteration 294 is 40867
# Best value at iteration 295 is 40867
# Best value at iteration 296 is 40867
# Best value at iteration 297 is 40867
# Best value at iteration 298 is 40867
# Best value at iteration 299 is 40759
# Best value at iteration 300 is 40759
# Best value at iteration 301 is 40759
# Best value at iteration 302 is 40759
# Best value at iteration 303 is 40692
# Best value at iteration 304 is 40685
# Best value at iteration 305 is 40685
# Best value at iteration 306 is 40685
# Best value at iteration 307 is 40664
# Best value at iteration 308 is 40664
# Best value at iteration 309 is 40664
# Best value at iteration 310 is 40664
# Best value at iteration 311 is 40664
# Best value at iteration 312 is 40664
# Best value at iteration 313 is 40664
# Best value at iteration 314 is 40664
# Best value at iteration 315 is 40664
# Best value at iteration 316 is 40664
# Best value at iteration 317 is 40664
# Best value at iteration 318 is 40664
# Best value at iteration 319 is 40664
# Best value at iteration 320 is 40664
# Best value at iteration 321 is 40664
# Best value at iteration 322 is 40664
# Best value at iteration 323 is 40664
# Best value at iteration 324 is 40664
# Best value at iteration 325 is 40664
# Best value at iteration 326 is 40664
# Best value at iteration 327 is 40664
# Best value at iteration 328 is 40664
# Best value at iteration 329 is 40634
# Best value at iteration 330 is 40634
# Best value at iteration 331 is 40634
# Best value at iteration 332 is 40634
# Best value at iteration 333 is 40634
# Best value at iteration 334 is 40634
# Best value at iteration 335 is 40634
# Best value at iteration 336 is 40634
# Best value at iteration 337 is 40634
# Best value at iteration 338 is 40634
# Best value at iteration 339 is 40634
# Best value at iteration 340 is 40634
# Best value at iteration 341 is 40634
# Best value at iteration 342 is 40634
# Best value at iteration 343 is 40634
# Best value at iteration 344 is 40634
# Best value at iteration 345 is 40634
# Best value at iteration 346 is 40634
# Best value at iteration 347 is 40634
# Best value at iteration 348 is 40634
# Best value at iteration 349 is 40634
# Best value at iteration 350 is 40634
# Best value at iteration 351 is 40634
# Best value at iteration 352 is 40634
# Best value at iteration 353 is 40634
# Best value at iteration 354 is 40634
# Best value at iteration 355 is 40634
# Best value at iteration 356 is 40634
# Best value at iteration 357 is 40634
# Best value at iteration 358 is 40634
# Best value at iteration 359 is 40634
# Best value at iteration 360 is 40634
# Best value at iteration 361 is 40634
# Best value at iteration 362 is 40634
# Best value at iteration 363 is 40634
# Best value at iteration 364 is 40634
# Best value at iteration 365 is 40634
# Best value at iteration 366 is 40634
# Best value at iteration 367 is 40634
# Best value at iteration 368 is 40634
# Best value at iteration 369 is 40634
# Best value at iteration 370 is 40634
# Best value at iteration 371 is 40634
# Best value at iteration 372 is 40634
# Best value at iteration 373 is 40634
# Best value at iteration 374 is 40634
# Best value at iteration 375 is 40634
# Best value at iteration 376 is 40634
# Best value at iteration 377 is 40634
# Best value at iteration 378 is 40634
# Best value at iteration 379 is 40634
# Best value at iteration 380 is 40634
# Best value at iteration 381 is 40634
# Best value at iteration 382 is 40634
# Best value at iteration 383 is 40634
# Best value at iteration 384 is 40634
# Best value at iteration 385 is 40634
# Best value at iteration 386 is 40634
# Best value at iteration 387 is 40634
# Best value at iteration 388 is 40634
# Best value at iteration 389 is 40634
# Best value at iteration 390 is 40634
# Best value at iteration 391 is 40634
# Best value at iteration 392 is 40634
# Best value at iteration 393 is 40634
# Best value at iteration 394 is 40634
# Best value at iteration 395 is 40634
# Best value at iteration 396 is 40634
# Best value at iteration 397 is 40634
# Best value at iteration 398 is 40634
# Best value at iteration 399 is 40634
# Best value at iteration 400 is 40634
# Best value at iteration 401 is 40634
# Best value at iteration 402 is 40634
# Best value at iteration 403 is 40634
# Best value at iteration 404 is 40634
# Best value at iteration 405 is 40634
# Best value at iteration 406 is 40634
# Best value at iteration 407 is 40634
# Best value at iteration 408 is 40634
# Best value at iteration 409 is 40634
# Best value at iteration 410 is 40634
# Best value at iteration 411 is 40634
# Best value at iteration 412 is 40634
# Best value at iteration 413 is 40634
# Best value at iteration 414 is 40634
# Best value at iteration 415 is 40634
# Best value at iteration 416 is 40634
# Best value at iteration 417 is 40634
# Best value at iteration 418 is 40634
# Best value at iteration 419 is 40634
# Best value at iteration 420 is 40634
# Best value at iteration 421 is 40634
# Best value at iteration 422 is 40634
# Best value at iteration 423 is 40634
# Best value at iteration 424 is 40634
# Best value at iteration 425 is 40634
# Best value at iteration 426 is 40634
# Best value at iteration 427 is 40634
# Best value at iteration 428 is 40634
# Best value at iteration 429 is 40634
# Best value at iteration 430 is 40634
# Best value at iteration 431 is 40634
# Best value at iteration 432 is 40634
# Best value at iteration 433 is 40634
# Best value at iteration 434 is 40634
# Best value at iteration 435 is 40634
# Best value at iteration 436 is 40634
# Best value at iteration 437 is 40634
# Best value at iteration 438 is 40634
# Best value at iteration 439 is 40634
# Best value at iteration 440 is 40634
# Best value at iteration 441 is 40634
# Best value at iteration 442 is 40634
# Best value at iteration 443 is 40634
# Best value at iteration 444 is 40634
# Best value at iteration 445 is 40634
# Best value at iteration 446 is 40634
# Best value at iteration 447 is 40634
# Best value at iteration 448 is 40634
# Best value at iteration 449 is 40634
# Best value at iteration 450 is 40634
# Best value at iteration 451 is 40634
# Best value at iteration 452 is 40634
# Best value at iteration 453 is 40634
# Best value at iteration 454 is 40634
# Best value at iteration 455 is 40634
# Best value at iteration 456 is 40634
# Best value at iteration 457 is 40634
# Best value at iteration 458 is 40634
# Best value at iteration 459 is 40634
# Best value at iteration 460 is 40634
# Best value at iteration 461 is 40634
# Best value at iteration 462 is 40634
# Best value at iteration 463 is 40634
# Best value at iteration 464 is 40634
# <ipython-input-10-af51fa5eef14>:46: RuntimeWarning: invalid value encountered in true_divide
#   P=U/U_sum # Fitness Scores
# Best value at iteration 465 is 40634
# Best value at iteration 466 is 40634
# Best value at iteration 467 is 40634
# Best value at iteration 468 is 40634
# Best value at iteration 469 is 40634
# Best value at iteration 470 is 40634
# Best value at iteration 471 is 40634
# Best value at iteration 472 is 40634
# Best value at iteration 473 is 40634
# Best value at iteration 474 is 40634
# Best value at iteration 475 is 40634
# Best value at iteration 476 is 40634
# Best value at iteration 477 is 40634
# Best value at iteration 478 is 40634
# Best value at iteration 479 is 40634
# Best value at iteration 480 is 40634
# Best value at iteration 481 is 40634
# Best value at iteration 482 is 40634
# Best value at iteration 483 is 40634
# Best value at iteration 484 is 40634
# Best value at iteration 485 is 40634
# Best value at iteration 486 is 40634
# Best value at iteration 487 is 40634
# Best value at iteration 488 is 40634
# Best value at iteration 489 is 40634
# Best value at iteration 490 is 40634
# Best value at iteration 491 is 40634
# Best value at iteration 492 is 40634
# Best value at iteration 493 is 40634
# Best value at iteration 494 is 40634
# Best value at iteration 495 is 40634
# Best value at iteration 496 is 40634
# Best value at iteration 497 is 40634
# Best value at iteration 498 is 40634
# Best value at iteration 499 is 40634
# Text(0.5, 1.0, 'Final Solution')
